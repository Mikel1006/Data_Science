# %% [markdown]
# <div style="text-align:center">
#         <a href="https://github.com/Mikel1006/Data_Science/tree/main">
#             <img src="https://raw.githubusercontent.com/Mikel1006/Data_Science/refs/heads/main/Ciencia_de_Dados_da_EBAC/Mod%2019/Data/data_science.png", alt="data_science" width=100%>
#         </a>
#     </div>
#
# # <span style="color: navy;"> **Profession: Data Scientist**
# ### **Module 20** | Markdown / Terminal | Exercise 1
#
# **Student:** [Mikel Tanner](https://www.linkedin.com/in/mikel-tanner/)<br>
# **Date:** 13th August 2025.

# %% [markdown]
# ## <div style="text-align:center"><span style="color: red" > Here is the original image.</span>

# %% [markdown]
# <img src="https://github.com/Mikel1006/Data_Science/blob/main/Ciencia_de_Dados_da_EBAC/Mod%2020%20/images/Cientista%20de%20Dados%20M20%20-%20Pratique.PNG?raw=true" >

# %% [markdown]
# ## <div style="text-align:center"><span style="color: green;"> Here is the reproduction of the above image (using LaTex).</span>

# %% [markdown]
# ### <div style="padding-left: 100px;"><span style="color: #2e5574;"> Fórmula de Bhaskara
#
# <div style="padding-left: 100px;">A solução para uma função de segundo grau depende das suas raízes (valores de x). Como já vimos, os coeficientes precisam ser <br>números reais e o angular diferente de zero. Sendo assim, temos a seguinte fórmula de Bhaskara:
#
# # <p> <center>  $x =\frac{-b \pm \sqrt{b²-4.a.c}}{2.a}$ <center></p>
# <p style="text-align:center"><i>Fórmula de Bhaskara.</i></p>
#
#
#
# Para melhor compreensão o seu cálculo é dividido em duas partes: discriminante da equação e operações para determinar as raízes.
#
# **Discriminante**
#
# A figura dentro da raiz na fórmula de Bhaskara é nomeada de discriminante. Seu símbolo é a letra grega delta e apresenta a <br>determinada fórmula:
# # <p> <center>$\Delta={b²{-4.a.c}}$</center> </p>
# <p style="text-align:center"><i>Fórmula da discriminante.</i></p>
#
#
# - Se o delta for maior que zero, a equação terá dois valores reais e distintos.
# - Se o delta for igual a zero, a equação terá somente um valor real ou dois resultados iguais.
# - Se o delta for menor que zero, a equação não possuirá valores reais.

# %% [markdown]
# ## <div style="text-align:center"><span style="color: red;">Here is a screenshot of the code I used to complete the exercise.
# ![{D3A30E3C-F245-42D8-83C8-A0D01D7CE01F}.png](attachment:338b71c1-81f3-455e-b195-8b8d464ce564.png)
