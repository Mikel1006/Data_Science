# %% [markdown]
# # EBAC - Regressão II - regressão múltipla
#
# ## Tarefa I

# %% [markdown]
# #### Previsão de renda II
#
# Vamos continuar trabalhando com a base 'previsao_de_renda.csv', que é a base do seu próximo projeto. Vamos usar os recursos que vimos até aqui nesta base.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
# importar a bibliotecas relevantes

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import r2_score

from scipy.stats import ks_2samp
import statsmodels.formula.api as smf
import statsmodels.api as sm
import patsy



import warnings
warnings.filterwarnings('ignore')

# %%
#Carregando Dataframe
dataset = pd.read_csv('previsao_de_renda.csv')
dataset.head()
# Out:
#    Unnamed: 0    data_ref  id_cliente sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01       15056    F             False             True
# 1           1  2015-01-01        9968    M              True             True
# 2           2  2015-01-01        4312    F              True             True
# 3           3  2015-01-01       10639    F             False             True
# 4           4  2015-01-01        7064    M              True            False
#
#    qtd_filhos        tipo_renda           educacao estado_civil  \
# 0           0        Empresário         Secundário     Solteiro
# 1           0       Assalariado  Superior completo       Casado
# 2           0        Empresário  Superior completo       Casado
# 3           1  Servidor público  Superior completo       Casado
# 4           0       Assalariado         Secundário     Solteiro
#
#   tipo_residencia  idade  tempo_emprego  qt_pessoas_residencia    renda
# 0            Casa     26       6.602740                    1.0  8060.34
# 1            Casa     28       7.183562                    2.0  1852.15
# 2            Casa     35       0.838356                    2.0  2253.89
# 3            Casa     30       4.846575                    3.0  6600.77
# 4   Governamental     33       4.293151                    1.0  6475.97

# %%
dataset.nunique()
# Out:
# Unnamed: 0               15000
# data_ref                    15
# id_cliente                9845
# sexo                         2
# posse_de_veiculo             2
# posse_de_imovel              2
# qtd_filhos                   8
# tipo_renda                   5
# educacao                     5
# estado_civil                 5
# tipo_residencia              6
# idade                       47
# tempo_emprego             2589
# qt_pessoas_residencia        9
# renda                     9786
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'data_ref', 'id_cliente', 'sexo', 'posse_de_veiculo',
#        'posse_de_imovel', 'qtd_filhos', 'tipo_renda', 'educacao',
#        'estado_civil', 'tipo_residencia', 'idade', 'tempo_emprego',
#        'qt_pessoas_residencia', 'renda'],
#       dtype='object')

# %%
#Vamos remover as varáveis irrelevantes
cols_a_usar = ['sexo', 'posse_de_veiculo',
       'posse_de_imovel', 'qtd_filhos', 'tipo_renda', 'educacao',
       'estado_civil', 'tipo_residencia', 'idade', 'tempo_emprego',
       'qt_pessoas_residencia', 'renda']
df_nova = dataset[cols_a_usar]
print(df_nova.shape)
df_nova.head()
# Out:
# (15000, 12)
#   sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos        tipo_renda  \
# 0    F             False             True           0        Empresário
# 1    M              True             True           0       Assalariado
# 2    F              True             True           0        Empresário
# 3    F             False             True           1  Servidor público
# 4    M              True            False           0       Assalariado
#
#             educacao estado_civil tipo_residencia  idade  tempo_emprego  \
# 0         Secundário     Solteiro            Casa     26       6.602740
# 1  Superior completo       Casado            Casa     28       7.183562
# 2  Superior completo       Casado            Casa     35       0.838356
# 3  Superior completo       Casado            Casa     30       4.846575
# 4         Secundário     Solteiro   Governamental     33       4.293151
#
#    qt_pessoas_residencia    renda
# 0                    1.0  8060.34
# 1                    2.0  1852.15
# 2                    2.0  2253.89
# 3                    3.0  6600.77
# 4                    1.0  6475.97

# %%
#Verificando NaN Values
df_nova.isna().sum()
# Out:
# sexo                        0
# posse_de_veiculo            0
# posse_de_imovel             0
# qtd_filhos                  0
# tipo_renda                  0
# educacao                    0
# estado_civil                0
# tipo_residencia             0
# idade                       0
# tempo_emprego            2573
# qt_pessoas_residencia       0
# renda                       0
# dtype: int64

# %%
# Substituir os NaN values na variável tempo_emprego por 0
df_nova['tempo_emprego'] = df_nova['tempo_emprego'].fillna(0)
df_nova.isna().sum()
# Out:
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# qt_pessoas_residencia    0
# renda                    0
# dtype: int64

# %%
# Verificando os datatypes
print(df_nova.dtypes)
# Out:
# sexo                      object
# posse_de_veiculo            bool
# posse_de_imovel             bool
# qtd_filhos                 int64
# tipo_renda                object
# educacao                  object
# estado_civil              object
# tipo_residencia           object
# idade                      int64
# tempo_emprego            float64
# qt_pessoas_residencia    float64
# renda                    float64
# dtype: object

# %%
#codificar as características categóricas
df_nova = pd.get_dummies(df_nova, drop_first=True)
print(df_nova.dtypes)
# Out:
# posse_de_veiculo                    bool
# posse_de_imovel                     bool
# qtd_filhos                         int64
# idade                              int64
# tempo_emprego                    float64
# qt_pessoas_residencia            float64
# renda                            float64
# sexo_M                              bool
# tipo_renda_Bolsista                 bool
# tipo_renda_Empresário               bool
# tipo_renda_Pensionista              bool
# tipo_renda_Servidor público         bool
# educacao_Pós graduação              bool
# educacao_Secundário                 bool
# educacao_Superior completo          bool
# educacao_Superior incompleto        bool
# estado_civil_Separado               bool
# estado_civil_Solteiro               bool
# estado_civil_União                  bool
# estado_civil_Viúvo                  bool
# tipo_residencia_Casa                bool
# tipo_residencia_Com os pais         bool
# tipo_residencia_Comunitário         bool
# tipo_residencia_Estúdio             bool
# tipo_residencia_Governamental       bool
# dtype: object

# %%
X = df_nova.drop('renda', axis=1)
y = df_nova['renda']
print(X.shape)
print(y.shape)
# Out:
# (15000, 24)
# (15000,)

# %% [markdown]
# 1. Separe a base em treinamento e teste (25% para teste, 75% para treinamento).
# 2. Rode uma regularização *ridge* com alpha = [0, 0.001, 0.005, 0.01, 0.05, 0.1] e avalie o $R^2$ na base de testes. Qual o melhor modelo?
# 3. Faça o mesmo que no passo 2, com uma regressão *LASSO*. Qual método chega a um melhor resultado?
# 4. Rode um modelo *stepwise*. Avalie o $R^2$ na vase de testes. Qual o melhor resultado?
# 5. Compare os parâmetros e avalie eventuais diferenças. Qual modelo você acha o melhor de todos?
# 6. Partindo dos modelos que você ajustou, tente melhorar o $R^2$ na base de testes. Use a criatividade, veja se consegue inserir alguma transformação ou combinação de variáveis.
# 7. Ajuste uma árvore de regressão e veja se consegue um $R^2$ melhor com ela.

# %% [markdown]
# ##### <span style="color:blue"> 1. Separe a base em treinamento e teste (25% para teste, 75% para treinamento)

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ##### <span style="color:blue"> 2. Rode uma regularização *ridge* com alpha = [0, 0.001, 0.005, 0.01, 0.05, 0.1] e avalie o $R^2$ na base de testes. Qual o melhor modelo?

# %%
alphas = [0, 0.001, 0.005, 0.01, 0.05, 0.1, 100]

# %%
# Testar cada alpha com Lasso Regression (L1)
for alpha in alphas:
    model_1 = Ridge(alpha=alpha)
    model_1.fit(train_X, train_y)
    y_pred = model_1.predict(test_X)
    r2_Ridge = r2_score(test_y, y_pred)
    
    print(f"Alpha: {alpha:.4f} -> R²(ridge): {r2_Ridge:.7f}")
# Out:
# Alpha: 0.0000 -> R²(ridge): 0.2684577
# Alpha: 0.0010 -> R²(ridge): 0.2684577
# Alpha: 0.0050 -> R²(ridge): 0.2684578
# Alpha: 0.0100 -> R²(ridge): 0.2684579
# Alpha: 0.0500 -> R²(ridge): 0.2684585
# Alpha: 0.1000 -> R²(ridge): 0.2684592
# Alpha: 100.0000 -> R²(ridge): 0.2685357

# %% [markdown]
# ##### <span style="color:green"> Observação:
# No output, todos os valores de ```𝑅2```  estão muito próximos, mas o maior deles é:
#
# 🔹 Alpha = 0.005 → 𝑅2=0.2684579

# %% [markdown]
# ##### <span style="color:blue"> 3. Faça o mesmo que no passo 2, com uma regressão *LASSO*. Qual método chega a um melhor resultado?

# %%
# Testar cada alpha com Lasso Regression (L1)
for alpha in alphas:
    model_2 = Lasso(alpha=alpha)
    model_2.fit(train_X, train_y)
    y_pred = model_2.predict(test_X)
    r2_lasso = r2_score(test_y, y_pred)
    
    print(f"Alpha: {alpha:.4f} -> R²(lasso): {r2_lasso:.7f}")
# Out:
# Alpha: 0.0000 -> R²(lasso): 0.2684578
# Alpha: 0.0010 -> R²(lasso): 0.2684579
# Alpha: 0.0050 -> R²(lasso): 0.2684584
# Alpha: 0.0100 -> R²(lasso): 0.2684590
# Alpha: 0.0500 -> R²(lasso): 0.2684635
# Alpha: 0.1000 -> R²(lasso): 0.2684684
# Alpha: 100.0000 -> R²(lasso): 0.2639023

# %% [markdown]
# ##### <span style="color:green"> Observação:
# O melhor resultado é o maior valor de ```𝑅2``` , pois indica a melhor explicação da variabilidade dos dados pelo modelo.
#
# 🔹 Alpha = 0.005 → 𝑅2=0.2684584

# %% [markdown]
# ##### <span style="color:blue"> 4. Rode um modelo *stepwise*. Avalie o $R^2$ na base de testes. Qual o melhor resultado?

# %%
df_nova.head()
# Out:
#    posse_de_veiculo  posse_de_imovel  qtd_filhos  idade  tempo_emprego  \
# 0             False             True           0     26       6.602740
# 1              True             True           0     28       7.183562
# 2              True             True           0     35       0.838356
# 3             False             True           1     30       4.846575
# 4              True            False           0     33       4.293151
#
#    qt_pessoas_residencia    renda  sexo_M  tipo_renda_Bolsista  \
# 0                    1.0  8060.34   False                False
# 1                    2.0  1852.15    True                False
# 2                    2.0  2253.89   False                False
# 3                    3.0  6600.77   False                False
# 4                    1.0  6475.97    True                False
#
#    tipo_renda_Empresário  ...  educacao_Superior incompleto  \
# 0                   True  ...                         False
# 1                  False  ...                         False
# 2                   True  ...                         False
# 3                  False  ...                         False
# 4                  False  ...                         False
#
#    estado_civil_Separado  estado_civil_Solteiro  estado_civil_União  \
# 0                  False                   True               False
# 1                  False                  False               False
# 2                  False                  False               False
# 3                  False                  False               False
# 4                  False                   True               False
#
#    estado_civil_Viúvo  tipo_residencia_Casa  tipo_residencia_Com os pais  \
# 0               False                  True                        False
# 1               False                  True                        False
# 2               False                  True                        False
# 3               False                  True                        False
# 4               False                 False                        False
#
#    tipo_residencia_Comunitário  tipo_residencia_Estúdio  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                    False
# 4                        False                    False
#
#    tipo_residencia_Governamental
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                           True
#
# [5 rows x 25 columns]

# %%
print(X.dtypes)
# Out:
# posse_de_veiculo                    bool
# posse_de_imovel                     bool
# qtd_filhos                         int64
# idade                              int64
# tempo_emprego                    float64
# qt_pessoas_residencia            float64
# sexo_M                              bool
# tipo_renda_Bolsista                 bool
# tipo_renda_Empresário               bool
# tipo_renda_Pensionista              bool
# tipo_renda_Servidor público         bool
# educacao_Pós graduação              bool
# educacao_Secundário                 bool
# educacao_Superior completo          bool
# educacao_Superior incompleto        bool
# estado_civil_Separado               bool
# estado_civil_Solteiro               bool
# estado_civil_União                  bool
# estado_civil_Viúvo                  bool
# tipo_residencia_Casa                bool
# tipo_residencia_Com os pais         bool
# tipo_residencia_Comunitário         bool
# tipo_residencia_Estúdio             bool
# tipo_residencia_Governamental       bool
# dtype: object

# %%
X = X.astype(float)

# %%
####Executando o modelo proposto de stepwise
def stepwise_selection(X, y, 
                        initial_list=[], 
                        threshold_in=0.01, 
                        threshold_out = 0.05, 
                        verbose=True):
        """ Perform a forward-backward feature selection 
        based on p-value from statsmodels.api.OLS
        Arguments:
            X - pandas.DataFrame with candidate features
            y - list-like with the target
            initial_list - list of features to start with (column names of X)
            threshold_in - include a feature if its p-value < threshold_in
            threshold_out - exclude a feature if its p-value > threshold_out
            verbose - whether to print the sequence of inclusions and exclusions
        Returns: list of selected features 
        Always set threshold_in < threshold_out to avoid infinite looping.
        See https://en.wikipedia.org/wiki/Stepwise_regression for the details
        """
        included = list(initial_list)
        #print("included")
        #print(included)
       
        while True:
            changed=False
            # forward step
            excluded = list(set(X.columns)-set(included))
            new_pval = pd.Series(index=excluded)
            
            for new_column in excluded:
                model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
                print("modelo 1")
                print(model.summary())
                new_pval[new_column] = model.pvalues[new_column]
                print("new_pval")
                print(new_pval)
                
            best_pval = new_pval.min()
            print("best_pval")
            print(best_pval)      
            if best_pval < threshold_in:
                print("best_pval")
                best_feature = new_pval.idxmin()
                included.append(best_feature)
                changed=True
                if verbose:
                    print("Entrou")
                    print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))
              
            
            #sys.exit()
            # backward step
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
            print("modelo 2")
            print(model.summary())
            # use all coefs except intercept
            pvalues = model.pvalues.iloc[1:]
            worst_pval = pvalues.max() # null if pvalues is empty
            print("worst_pval")
            print(worst_pval) 
            if worst_pval > threshold_out:
                changed=True
                worst_feature = pvalues.idxmax()
                included.remove(worst_feature)
                if verbose:
                    print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
            if not changed:
                break
        return included

result = stepwise_selection(X, y)
# Out:
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     1327.
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):          2.04e-278
# Time:                        00:10:36   Log-Likelihood:            -1.5595e+05
# No. Observations:               15000   AIC:                         3.119e+05
# Df Residuals:                   14998   BIC:                         3.119e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4060.5833     78.773     51.548      0.000    3906.178    4214.988
# sexo_M      5029.8210    138.092     36.424      0.000    4759.143    5300.499
# ==============================================================================
# Omnibus:                    21825.532   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12898650.997
# Skew:                           8.615   Prob(JB):                         0.00
# Kurtosis:                     145.622   Cond. No.                         2.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista                     NaN
# educacao_Superior incompleto               NaN
# educacao_Secundário                        NaN
# posse_de_veiculo                           NaN
# estado_civil_União                         NaN
# tipo_residencia_Governamental              NaN
# estado_civil_Viúvo                         NaN
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     189.8
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           6.26e-43
# Time:                        00:10:36   Log-Likelihood:            -1.5649e+05
# No. Observations:               15000   AIC:                         3.130e+05
# Df Residuals:                   14998   BIC:                         3.130e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   6118.7245     73.722     82.998      0.000    5974.221    6263.228
# tipo_renda_Pensionista -2448.3197    177.690    -13.779      0.000   -2796.614   -2100.026
# ==============================================================================
# Omnibus:                    21520.789   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11330360.306
# Skew:                           8.420   Prob(JB):                         0.00
# Kurtosis:                     136.585   Cond. No.                         2.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto               NaN
# educacao_Secundário                        NaN
# posse_de_veiculo                           NaN
# estado_civil_União                         NaN
# tipo_residencia_Governamental              NaN
# estado_civil_Viúvo                         NaN
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     6.832
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):            0.00896
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                         5732.6325     68.827     83.291      0.000    5597.724    5867.541
# educacao_Superior incompleto  -915.6839    350.318     -2.614      0.009   -1602.350    -229.018
# ==============================================================================
# Omnibus:                    21461.622   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11037418.869
# Skew:                           8.383   Prob(JB):                         0.00
# Kurtosis:                     134.829   Cond. No.                         5.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário                        NaN
# posse_de_veiculo                           NaN
# estado_civil_União                         NaN
# tipo_residencia_Governamental              NaN
# estado_civil_Viúvo                         NaN
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     8.066
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):            0.00452
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                5928.6336    105.777     56.048      0.000    5721.297    6135.970
# educacao_Secundário  -390.1291    137.362     -2.840      0.005    -659.375    -120.883
# ==============================================================================
# Omnibus:                    21489.001   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11120206.337
# Skew:                           8.402   Prob(JB):                         0.00
# Kurtosis:                     135.325   Cond. No.                         2.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                           NaN
# estado_civil_União                         NaN
# tipo_residencia_Governamental              NaN
# estado_civil_Viúvo                         NaN
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     153.0
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           5.66e-35
# Time:                        00:10:36   Log-Likelihood:            -1.5651e+05
# No. Observations:               15000   AIC:                         3.130e+05
# Df Residuals:                   14998   BIC:                         3.130e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             5032.1161     86.035     58.489      0.000    4863.477    5200.755
# posse_de_veiculo  1702.6561    137.649     12.370      0.000    1432.848    1972.465
# ==============================================================================
# Omnibus:                    21538.649   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11279101.818
# Skew:                           8.437   Prob(JB):                         0.00
# Kurtosis:                     136.274   Cond. No.                         2.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                         NaN
# tipo_residencia_Governamental              NaN
# estado_civil_Viúvo                         NaN
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     11.13
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           0.000850
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5759.9338     70.039     82.239      0.000    5622.649    5897.219
# estado_civil_União  -871.7082    261.263     -3.337      0.001   -1383.815    -359.602
# ==============================================================================
# Omnibus:                    21458.731   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11033741.111
# Skew:                           8.381   Prob(JB):                         0.00
# Kurtosis:                     134.807   Cond. No.                         3.89
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental              NaN
# estado_civil_Viúvo                         NaN
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.3641
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):              0.546
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          5690.1076     68.540     83.018      0.000    5555.760    5824.455
# tipo_residencia_Governamental   238.2568    394.841      0.603      0.546    -535.680    1012.193
# ==============================================================================
# Omnibus:                    21457.934   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11012276.965
# Skew:                           8.381   Prob(JB):                         0.00
# Kurtosis:                     134.676   Cond. No.                         5.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                         NaN
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     39.14
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           4.06e-10
# Time:                        00:10:36   Log-Likelihood:            -1.5656e+05
# No. Observations:               15000   AIC:                         3.131e+05
# Df Residuals:                   14998   BIC:                         3.131e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5791.3588     69.069     83.848      0.000    5655.974    5926.743
# estado_civil_Viúvo -1984.6357    317.246     -6.256      0.000   -2606.478   -1362.794
# ==============================================================================
# Omnibus:                    21473.694   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11094343.171
# Skew:                           8.390   Prob(JB):                         0.00
# Kurtosis:                     135.172   Cond. No.                         4.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário                      NaN
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.388
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):              0.122
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  5639.6646     77.112     73.136      0.000    5488.516    5790.813
# tipo_renda_Empresário   246.3900    159.454      1.545      0.122     -66.160     558.940
# ==============================================================================
# Omnibus:                    21475.149   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11071049.672
# Skew:                           8.393   Prob(JB):                         0.00
# Kurtosis:                     135.030   Cond. No.                         2.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário             1.223171e-01
# tipo_residencia_Casa                       NaN
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1227
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):              0.726
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 5625.5105    215.768     26.072      0.000    5202.578    6048.443
# tipo_residencia_Casa    79.5631    227.171      0.350      0.726    -365.719     524.846
# ==============================================================================
# Omnibus:                    21465.188   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11045467.689
# Skew:                           8.385   Prob(JB):                         0.00
# Kurtosis:                     134.877   Cond. No.                         6.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário             1.223171e-01
# tipo_residencia_Casa              7.261674e-01
# tipo_residencia_Comunitário                NaN
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.357
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):              0.244
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        5702.4347     67.642     84.303      0.000    5569.848    5835.021
# tipo_residencia_Comunitário -1206.4824   1035.551     -1.165      0.244   -3236.289     823.325
# ==============================================================================
# Omnibus:                    21463.913   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11039591.355
# Skew:                           8.385   Prob(JB):                         0.00
# Kurtosis:                     134.841   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário             1.223171e-01
# tipo_residencia_Casa              7.261674e-01
# tipo_residencia_Comunitário       2.440121e-01
# posse_de_imovel                            NaN
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.2257
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):              0.635
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            5650.9409    118.622     47.638      0.000    5418.427    5883.455
# posse_de_imovel    68.5391    144.254      0.475      0.635    -214.216     351.295
# ==============================================================================
# Omnibus:                    21465.901   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11046134.184
# Skew:                           8.386   Prob(JB):                         0.00
# Kurtosis:                     134.881   Cond. No.                         3.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário             1.223171e-01
# tipo_residencia_Casa              7.261674e-01
# tipo_residencia_Comunitário       2.440121e-01
# posse_de_imovel                   6.347028e-01
# tipo_renda_Bolsista                        NaN
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.07861
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):              0.779
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                5697.7508     67.521     84.385      0.000    5565.402    5830.099
# tipo_renda_Bolsista  -772.8396   2756.517     -0.280      0.779   -6175.950    4630.271
# ==============================================================================
# Omnibus:                    21463.985   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11038776.442
# Skew:                           8.385   Prob(JB):                         0.00
# Kurtosis:                     134.836   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário             1.223171e-01
# tipo_residencia_Casa              7.261674e-01
# tipo_residencia_Comunitário       2.440121e-01
# posse_de_imovel                   6.347028e-01
# tipo_renda_Bolsista               7.791989e-01
# estado_civil_Separado                      NaN
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.920
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):              0.166
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  5720.6230     69.565     82.234      0.000    5584.267    5856.979
# estado_civil_Separado  -398.2251    287.371     -1.386      0.166    -961.508     165.058
# ==============================================================================
# Omnibus:                    21461.875   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11032807.056
# Skew:                           8.383   Prob(JB):                         0.00
# Kurtosis:                     134.801   Cond. No.                         4.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário             1.223171e-01
# tipo_residencia_Casa              7.261674e-01
# tipo_residencia_Comunitário       2.440121e-01
# posse_de_imovel                   6.347028e-01
# tipo_renda_Bolsista               7.791989e-01
# estado_civil_Separado             1.658435e-01
# tipo_residencia_Com os pais                NaN
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     4.454
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):             0.0348
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        5728.2067     69.062     82.943      0.000    5592.836    5863.577
# tipo_residencia_Com os pais  -687.1027    325.563     -2.111      0.035   -1325.245     -48.960
# ==============================================================================
# Omnibus:                    21460.861   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11034584.204
# Skew:                           8.382   Prob(JB):                         0.00
# Kurtosis:                     134.812   Cond. No.                         4.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# estado_civil_Viúvo                4.061722e-10
# tipo_renda_Empresário             1.223171e-01
# tipo_residencia_Casa              7.261674e-01
# tipo_residencia_Comunitário       2.440121e-01
# posse_de_imovel                   6.347028e-01
# tipo_renda_Bolsista               7.791989e-01
# estado_civil_Separado             1.658435e-01
# tipo_residencia_Com os pais       3.483115e-02
# qtd_filhos                                 NaN
# qt_pessoas_residencia                      NaN
# estado_civil_Solteiro                      NaN
# tempo_emprego                              NaN
# educacao_Pós graduação                     NaN
# idade                                      NaN
# tipo_renda_Servidor público                NaN
# tipo_residencia_Estúdio                    NaN
# educacao_Superior completo                 NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     12.93
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):           0.000325
# Time:                        00:10:36   Log-Likelihood:            -1.5658e+05
# No. Observations:               15000   AIC:                         3.132e+05
# Df Residuals:                   14998   BIC:                         3.132e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5556.8123     77.967     71.271      0.000    5403.987    5709.638
# qtd_filhos   324.9222     90.371      3.595      0.000     147.784     502.060
# ==============================================================================
# Omnibus:                    21486.967   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         11120252.993
# Skew:                           8.400   Prob(JB):                         0.00
# Kurtosis:                     135.326   Cond. No.                         1.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# sexo_M                           2.044546e-278
# tipo_renda_Pensionista            6.259895e-43
# educacao_Superior incompleto      8.961403e-03
# educacao_Secundário               4.515183e-03
# posse_de_veiculo                  5.655201e-35
# estado_civil_União                8.503960e-04
# tipo_residencia_Governamental     5.462354e-01
# ...
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     590.1
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:10:39   Log-Likelihood:            -1.5431e+05
# No. Observations:               15000   AIC:                         3.086e+05
# Df Residuals:                   14990   BIC:                         3.087e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                      -3087.6101    410.668     -7.519      0.000   -3892.569   -2282.651
# tempo_emprego                553.1277     10.086     54.842      0.000     533.358     572.897
# sexo_M                      5890.4557    128.658     45.784      0.000    5638.270    6142.641
# tipo_renda_Pensionista      2655.1017    234.198     11.337      0.000    2196.045    3114.158
# tipo_renda_Empresário        785.9099    143.169      5.489      0.000     505.281    1066.539
# idade                         43.6430      7.386      5.909      0.000      29.166      58.120
# educacao_Superior completo   659.5020    122.609      5.379      0.000     419.173     899.831
# posse_de_imovel              371.0573    125.516      2.956      0.003     125.032     617.083
# qt_pessoas_residencia        141.9545     76.808      1.848      0.065      -8.599     292.508
# estado_civil_Solteiro       -211.9490    201.929     -1.050      0.294    -607.755     183.857
# ==============================================================================
# Omnibus:                    21877.831   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15425049.384
# Skew:                           8.576   Prob(JB):                         0.00
# Kurtosis:                     159.160   Cond. No.                         339.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# tipo_residencia_Comunitário      0.799699
# tipo_renda_Bolsista              0.548735
# educacao_Superior incompleto     0.203921
# estado_civil_Separado            0.764732
# tipo_residencia_Com os pais      0.649791
# educacao_Secundário              0.244059
# posse_de_veiculo                 0.811933
# qtd_filhos                       0.496703
# estado_civil_União               0.035231
# tipo_residencia_Governamental    0.077318
# educacao_Pós graduação           0.731120
# estado_civil_Viúvo               0.775916
# estado_civil_Solteiro            0.293910
# tipo_residencia_Casa                  NaN
# tipo_renda_Servidor público           NaN
# tipo_residencia_Estúdio               NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     590.1
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:10:39   Log-Likelihood:            -1.5431e+05
# No. Observations:               15000   AIC:                         3.086e+05
# Df Residuals:                   14990   BIC:                         3.087e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                      -3136.2474    400.205     -7.837      0.000   -3920.698   -2351.796
# tempo_emprego                553.0131     10.084     54.843      0.000     533.248     572.778
# sexo_M                      5887.6798    128.713     45.743      0.000    5635.387    6139.973
# tipo_renda_Pensionista      2651.2109    234.135     11.323      0.000    2192.278    3110.144
# tipo_renda_Empresário        787.7803    143.216      5.501      0.000     507.060    1068.500
# idade                         45.7678      7.264      6.301      0.000      31.529      60.006
# educacao_Superior completo   656.0142    122.566      5.352      0.000     415.770     896.258
# posse_de_imovel              386.9941    127.397      3.038      0.002     137.280     636.709
# qt_pessoas_residencia        181.6420     68.374      2.657      0.008      47.620     315.664
# tipo_residencia_Casa        -183.1662    200.720     -0.913      0.361    -576.601     210.269
# ==============================================================================
# Omnibus:                    21876.642   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15408605.203
# Skew:                           8.575   Prob(JB):                         0.00
# Kurtosis:                     159.076   Cond. No.                         328.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# tipo_residencia_Comunitário      0.799699
# tipo_renda_Bolsista              0.548735
# educacao_Superior incompleto     0.203921
# estado_civil_Separado            0.764732
# tipo_residencia_Com os pais      0.649791
# educacao_Secundário              0.244059
# posse_de_veiculo                 0.811933
# qtd_filhos                       0.496703
# estado_civil_União               0.035231
# tipo_residencia_Governamental    0.077318
# educacao_Pós graduação           0.731120
# estado_civil_Viúvo               0.775916
# estado_civil_Solteiro            0.293910
# tipo_residencia_Casa             0.361495
# tipo_renda_Servidor público           NaN
# tipo_residencia_Estúdio               NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     590.0
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:10:39   Log-Likelihood:            -1.5431e+05
# No. Observations:               15000   AIC:                         3.086e+05
# Df Residuals:                   14990   BIC:                         3.087e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -3267.5140    379.352     -8.613      0.000   -4011.091   -2523.937
# tempo_emprego                 552.0548     10.144     54.421      0.000     532.171     571.939
# sexo_M                       5894.3083    128.774     45.773      0.000    5641.896    6146.721
# tipo_renda_Pensionista       2660.2851    234.973     11.322      0.000    2199.709    3120.861
# tipo_renda_Empresário         801.9635    146.331      5.480      0.000     515.138    1088.789
# idade                          45.2358      7.237      6.250      0.000      31.050      59.422
# educacao_Superior completo    649.3367    123.098      5.275      0.000     408.050     890.624
# posse_de_imovel               367.4885    125.458      2.929      0.003     121.576     613.401
# qt_pessoas_residencia         178.5553     68.307      2.614      0.009      44.665     312.446
# tipo_renda_Servidor público   128.2531    218.240      0.588      0.557    -299.525     556.031
# ==============================================================================
# Omnibus:                    21884.453   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15451288.991
# Skew:                           8.581   Prob(JB):                         0.00
# Kurtosis:                     159.293   Cond. No.                         309.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# tipo_residencia_Comunitário      0.799699
# tipo_renda_Bolsista              0.548735
# educacao_Superior incompleto     0.203921
# estado_civil_Separado            0.764732
# tipo_residencia_Com os pais      0.649791
# educacao_Secundário              0.244059
# posse_de_veiculo                 0.811933
# qtd_filhos                       0.496703
# estado_civil_União               0.035231
# tipo_residencia_Governamental    0.077318
# educacao_Pós graduação           0.731120
# estado_civil_Viúvo               0.775916
# estado_civil_Solteiro            0.293910
# tipo_residencia_Casa             0.361495
# tipo_renda_Servidor público      0.556764
# tipo_residencia_Estúdio               NaN
# dtype: float64
# modelo 1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     590.0
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:10:39   Log-Likelihood:            -1.5431e+05
# No. Observations:               15000   AIC:                         3.086e+05
# Df Residuals:                   14990   BIC:                         3.087e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                      -3251.0538    378.753     -8.584      0.000   -3993.455   -2508.652
# tempo_emprego                552.6358     10.081     54.821      0.000     532.876     572.395
# sexo_M                      5887.9680    128.812     45.710      0.000    5635.481    6140.455
# tipo_renda_Pensionista      2648.4438    234.121     11.312      0.000    2189.538    3107.350
# tipo_renda_Empresário        782.7898    143.190      5.467      0.000     502.120    1063.459
# idade                         45.1291      7.238      6.235      0.000      30.942      59.316
# educacao_Superior completo   654.8106    122.593      5.341      0.000     414.514     895.107
# posse_de_imovel              368.0199    125.477      2.933      0.003     122.069     613.971
# qt_pessoas_residencia        178.2997     68.314      2.610      0.009      44.396     312.203
# tipo_residencia_Estúdio      395.7126    783.834      0.505      0.614   -1140.697    1932.122
# ==============================================================================
# Omnibus:                    21882.156   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15441610.629
# Skew:                           8.579   Prob(JB):                         0.00
# Kurtosis:                     159.244   Cond. No.                         619.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# new_pval
# tipo_residencia_Comunitário      0.799699
# tipo_renda_Bolsista              0.548735
# educacao_Superior incompleto     0.203921
# estado_civil_Separado            0.764732
# tipo_residencia_Com os pais      0.649791
# educacao_Secundário              0.244059
# posse_de_veiculo                 0.811933
# qtd_filhos                       0.496703
# estado_civil_União               0.035231
# tipo_residencia_Governamental    0.077318
# educacao_Pós graduação           0.731120
# estado_civil_Viúvo               0.775916
# estado_civil_Solteiro            0.293910
# tipo_residencia_Casa             0.361495
# tipo_renda_Servidor público      0.556764
# tipo_residencia_Estúdio          0.613677
# dtype: float64
# best_pval
# 0.03523103233133264
# modelo 2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     663.7
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:10:39   Log-Likelihood:            -1.5431e+05
# No. Observations:               15000   AIC:                         3.086e+05
# Df Residuals:                   14991   BIC:                         3.087e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                      -3254.3851    378.686     -8.594      0.000   -3996.655   -2512.115
# tempo_emprego                552.7297     10.079     54.841      0.000     532.974     572.485
# sexo_M                      5891.1232    128.657     45.789      0.000    5638.940    6143.307
# tipo_renda_Pensionista      2648.5323    234.115     11.313      0.000    2189.638    3107.427
# tipo_renda_Empresário        784.1684    143.160      5.478      0.000     503.557    1064.780
# idade                         45.1933      7.237      6.245      0.000      31.008      59.378
# educacao_Superior completo   656.0427    122.565      5.353      0.000     415.800     896.286
# posse_de_imovel              366.7404    125.449      2.923      0.003     120.846     612.635
# qt_pessoas_residencia        178.8276     68.304      2.618      0.009      44.943     312.712
# ==============================================================================
# Omnibus:                    21880.532   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15435097.873
# Skew:                           8.578   Prob(JB):                         0.00
# Kurtosis:                     159.211   Cond. No.                         309.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# worst_pval
# 0.00885080413384379

# %%
reg_stepwise = sm.OLS(y, sm.add_constant(pd.DataFrame(X))).fit()
reg_stepwise.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  renda   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.261
# Method:                 Least Squares   F-statistic:                     221.7
# Date:                Sun, 16 Mar 2025   Prob (F-statistic):               0.00
# Time:                        00:10:39   Log-Likelihood:            -1.5430e+05
# No. Observations:               15000   AIC:                         3.087e+05
# Df Residuals:                   14975   BIC:                         3.088e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                         -4878.6701   2229.392     -2.188      0.029   -9248.551    -508.789
# posse_de_veiculo                  6.2182    129.843      0.048      0.962    -248.291     260.727
# posse_de_imovel                 387.4028    127.962      3.027      0.002     136.581     638.224
# qtd_filhos                    -1016.5059   1040.217     -0.977      0.328   -3055.458    1022.446
# idade                            40.6791      7.559      5.381      0.000      25.862      55.497
# tempo_emprego                   552.7427     10.172     54.338      0.000     532.804     572.681
# qt_pessoas_residencia          1146.5441   1038.281      1.104      0.269    -888.613    3181.701
# sexo_M                         5879.7270    137.106     42.885      0.000    5610.982    6148.472
# tipo_renda_Bolsista           -1433.4495   2374.406     -0.604      0.546   -6087.576    3220.677
# tipo_renda_Empresário           810.8514    146.884      5.520      0.000     522.940    1098.763
# tipo_renda_Pensionista         2690.2177    236.476     11.376      0.000    2226.697    3153.739
# tipo_renda_Servidor público     124.9884    218.593      0.572      0.567    -303.480     553.457
# educacao_Pós graduação          625.2472   1504.206      0.416      0.678   -2323.181    3573.676
# educacao_Secundário             154.1790    560.479      0.275      0.783    -944.429    1252.787
# educacao_Superior completo      783.0261    564.938      1.386      0.166    -324.321    1890.373
# educacao_Superior incompleto   -218.7200    631.907     -0.346      0.729   -1457.334    1019.894
# estado_civil_Separado           982.7116   1067.829      0.920      0.357   -1110.363    3075.787
# estado_civil_Solteiro           733.9742   1047.273      0.701      0.483   -1318.809    2786.757
# estado_civil_União             -493.0130    228.952     -2.153      0.031    -941.787     -44.239
# estado_civil_Viúvo              983.5765   1077.717      0.913      0.361   -1128.881    3096.034
# tipo_residencia_Casa           -213.1983    517.574     -0.412      0.680   -1227.707     801.311
# tipo_residencia_Com os pais    -288.5781    580.819     -0.497      0.619   -1427.055     849.899
# tipo_residencia_Comunitário    -421.3319   1029.140     -0.409      0.682   -2438.573    1595.909
# tipo_residencia_Estúdio         186.2067    935.434      0.199      0.842   -1647.359    2019.773
# tipo_residencia_Governamental   360.9207    614.680      0.587      0.557    -843.928    1565.769
# ==============================================================================
# Omnibus:                    21863.118   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15345272.223
# Skew:                           8.566   Prob(JB):                         0.00
# Kurtosis:                     158.753   Cond. No.                     2.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Definir X e y
X = df_nova[result]
y = df_nova['renda']

X = np.asarray(X, dtype=np.float64)
y = np.asarray(y, dtype=np.float64)

# %%
# Dividir os dados em treino e teste
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=42)

# Adiciona a constante (intercepto)
train_X = sm.add_constant(train_X)
test_X = sm.add_constant(test_X)

# Ajusta o modelo OLS e faz previsões
model = sm.OLS(train_y, train_X).fit()
y_pred = model.predict(test_X)

# Calcula o R²
print(f'R-squared: {r2_score(test_y, y_pred):.4f}')
# Out:
# R-squared: 0.2690

# %%
# RIDGE FIT
alphas = [0, 0.001, 0.005, 0.01, 0.05, 0.1]
r2_y_pred = []

for alpha in alphas:
    md = sm.OLS(train_y, train_X)
    reg = md.fit_regularized(method='elastic_net', 
                             refit=True, 
                             L1_wt=0,  # ridge fit
                             alpha=alpha)
    y_pred = reg.predict(test_X)
    r2 = r2_score(test_y, y_pred)
    
    r2_y_pred.append(r2)
    print(f'Alpha {alpha}: \nR-squared = {r2}\n')
    
pd.DataFrame({'alpha':alphas, 
              '𝑅2-Ridge':r2_y_pred
             }).sort_values(by='𝑅2-Ridge', ascending=False)
# Out:
# Alpha 0:
# R-squared = 0.26901118051565687
#
# Alpha 0.001:
# R-squared = 0.2689469332209887
#
# Alpha 0.005:
# R-squared = 0.26857355767672975
#
# Alpha 0.01:
# R-squared = 0.26793239547468195
#
# Alpha 0.05:
# R-squared = 0.2606171843325742
#
# Alpha 0.1:
# R-squared = 0.2509899778318002
#    alpha  𝑅2-Ridge
# 0  0.000  0.269011
# 1  0.001  0.268947
# 2  0.005  0.268574
# 3  0.010  0.267932
# 4  0.050  0.260617
# 5  0.100  0.250990

# %%
# LASSO FIT
alphas = [0, 0.001, 0.005, 0.01, 0.05, 0.1]
r2_y_pred = []

for alpha in alphas:
    md = sm.OLS(train_y, train_X)
    reg = md.fit_regularized(method='elastic_net', 
                             refit=True, 
                             L1_wt=1,  # lasso fit
                             alpha=alpha)
    y_pred = reg.predict(test_X)
    r2 = r2_score(test_y, y_pred)
    
    r2_y_pred.append(r2)
    print(f'Alpha {alpha}: \nR-squared = {r2}\n')
    
pd.DataFrame({'alpha ':alphas, 
              '𝑅2-Lasso':r2_y_pred
             }).sort_values(by='𝑅2-Lasso', ascending=False)
# Out:
# Alpha 0:
# R-squared = 0.26901118051565687
#
# Alpha 0.001:
# R-squared = 0.26901118051565687
#
# Alpha 0.005:
# R-squared = 0.26901118051565687
#
# Alpha 0.01:
# R-squared = 0.26901118051565687
#
# Alpha 0.05:
# R-squared = 0.26901118051565687
#
# Alpha 0.1:
# R-squared = 0.26901118051565687
#    alpha   𝑅2-Lasso
# 0   0.000  0.269011
# 1   0.001  0.269011
# 2   0.005  0.269011
# 3   0.010  0.269011
# 4   0.050  0.269011
# 5   0.100  0.269011

# %% [markdown]
# ##### <span style="color:blue"> 5. Compare os parâmetros e avalie eventuais diferenças. Qual modelo você acha o melhor de todos?

# %% [markdown]
# ##### <span style="color:green"> Observação:
# Os resultados da regressão Ridge variam com diferentes valores alfa, enquanto os resultados da regressão Lasso permanecem constantes para todos os valores de alfa.
#
# - **Regressão Ridge**: A melhor pontuação R² é **0,2690** quando alfa = 0.
# - **Regressão Lasso**: A pontuação R² permanece constante em **0,2690** para todos os valores alfa.
#
# Como Lasso não melhora R² e Ridge atinge uma pontuação ligeiramente melhor em alfa = 0,001 (**0,2689**), **Ridge tem um desempenho ligeiramente melhor** neste caso, pois permite alguma flexibilidade no ajuste do modelo. No entanto, a melhoria é mínima.

# %% [markdown]
# ##### <span style="color:blue"> 6. Partindo dos modelos que você ajustou, tente melhorar o $R^2$ na base de testes. Use a criatividade, veja se consegue inserir alguma transformação ou combinação de variáveis.

# %% [markdown]
# variaveis_eficientes => ["sexo_M", "idade", "tempo_emprego", "tipo_renda_Pensionista", "tipo_renda_Empresário",
#     "posse_de_imovel",
#     "tipo_renda_Bolsista"
# ]

# %% [markdown]
# ##### <span style="color:blue"> 7. Ajuste uma árvore de regressão e veja se consegue um $R^2$ melhor com ela.
